# %%
class BaseCharacter:
    def __init__(
        self, 
        name, 
        age, 
        gender
    ):
        self.name = name
        self.age = age
        self.gender = gender

class Robert(
    BaseCharacter, 
    flying,
    walking, 
    Playable
):
    def __init__(
        self, 
        name,
        age,
        gender
    ):
        super().__init__(name, age, gender)

class Steve(
    BaseCharacter,
    walking,
    swimming,
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

class Jimmy(
    BaseCharacter, 
    flying,
    swimming,
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

class Jessi(
    BaseCharacter,
    flying,
    walking, 
    swimming, 
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)
