# %%
class flying:
    def fly(self):
        print('I fly!')

class walking:
    def walk(self):
        print('I walk!')

class swimming:
    def swim(self):
        print('I swim!')

# %%
class Playable:
    def MixinJumpable(self):
        print('I jump!')
    
    def MixinAttackable(self):
        print('I am attacking!')
    
    def MixinUsable(self):
        print('I am using item!')

class FunkoPop(
    BaseCharacter, 
    flying,
    walking
):
    def __init__(
        self,
        name,
        age, 
        gender, 
        size, 
        material, 
        limited_edition
    ):
        super().__init__(name, age, gender)
        self.size = size
        self.material = material
        self.limited_edition = limited_edition

# %%
class BaseCharacter:
    def __init__(
        self, 
        name, 
        age, 
        gender
    ):
        self.name = name
        self.age = age
        self.gender = gender

class Robert(
    BaseCharacter, 
    flying,
    walking, 
    Playable
):
    def __init__(
        self, 
        name,
        age,
        gender
    ):
        super().__init__(name, age, gender)

class Steve(
    BaseCharacter,
    walking,
    swimming,
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

class Jimmy(
    BaseCharacter, 
    flying,
    swimming,
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

class Jessi(
    BaseCharacter,
    flying,
    walking, 
    swimming, 
    Playable
):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)
