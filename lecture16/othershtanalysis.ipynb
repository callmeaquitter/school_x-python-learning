# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import pymorphy2
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
with open("C:\\Users\\User\\Downloads\\Cezar_i_Kleopatra.txt", 'r', encoding = 'cp1251', errors='ignore') as f1:
    text1 = f1.read()

with open("C:\\Users\\User\\Downloads\\Pigmalion.txt", 'r', encoding = 'cp1251', errors='ignore') as f2:
    text2 = f2.read()

with open("C:\\Users\\User\\Downloads\\Telezhka_s_yablokami.txt", 'r', encoding = 'cp1251', errors='ignore') as f3:
    text3 = f3.read()

with open("C:\\Users\\User\\Downloads\\Uchenik_dyavola.txt", 'r', encoding = 'cp1251', errors='ignore') as f4:
    text4 = f4.read()

with open("C:\\Users\\User\\Downloads\\Mayor_Barbara.txt", 'r', encoding = 'cp1251', errors='ignore') as f5:
    text5 = f5.read()

with open("C:\\Users\\User\\Downloads\\Nazad_k_Mafusailu.txt", 'r', encoding = 'cp1251', errors='ignore') as f6:
    text6 = f6.read()

# %%
tokenized1 = nltk.word_tokenize(text1)
tokenized1

tagged1 = nltk.pos_tag(tokenized1)
tagged1


lemm1 = WordNetLemmatizer()
lemmatized1 = [lemm1.lemmatize(word) for word in tokenized1]
lemmatized1

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged1


morph = pymorphy2.MorphAnalyzer()
lemmas1 = [morph.parse(token)[0].normal_form for token in tokenized1]

tokenized1

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Cezar_i_Kleopatra.txt", 'r', encoding = 'cp1251', errors='ignore') as f1:
    text1 = f1.read()
tokenized1 = nltk.word_tokenize(text1)
stemmed1 = [stemmer.stem(word) for word in tokenized1]
stemmed1
# Out:
# ['бернард',
#  'шо',
#  'цезар',
#  'и',
#  'клеопатр',
#  'историческ',
#  'пьес',
#  'пролог',
#  'врат',
#  'храм',
#  'бог',
#  'ра',
#  'в',
#  'мемфис',
#  '.',
#  'глубок',
#  'сумрак',
#  '.',
#  'величествен',
#  'существ',
#  'с',
#  'голов',
#  'сокол',
#  ',',
#  'излуча',
#  'таинствен',
#  'свет',
#  ',',
#  'выступа',
#  'из',
#  'мрак',
#  'в',
#  'глубин',
#  'храм',
#  '.',
#  'бог',
#  'с',
#  'величайш',
#  'презрен',
#  'окидыва',
#  'взор',
#  'современ',
#  'аудитор',
#  'и',
#  'посл',
#  'некотор',
#  'пауз',
#  'обраща',
#  'к',
#  'не',
#  'со',
#  'след',
#  'слов',
#  ':',
#  '–',
#  'молчан',
#  '!',
#  'умолкн',
#  'и',
#  'слуша',
#  'мен',
#  'вы',
#  ',',
#  'чопорн',
#  'маленьк',
#  'островитян',
#  '!',
#  'внемл',
#  'мне',
#  'вы',
#  ',',
#  'мужчин',
#  ',',
#  'что',
#  'нос',
#  'на',
#  'груд',
#  'сво',
#  'бел',
#  'папирус',
#  ',',
#  'на',
#  'котор',
#  'не',
#  'начерта',
#  'нич',
#  '(',
#  'даб',
#  'изоблич',
#  'младенческ',
# ...

# %%
tokenized2 = nltk.word_tokenize(text2)
tokenized2

tagged2 = nltk.pos_tag(tokenized2)
tagged2


lemm2 = WordNetLemmatizer()
lemmatized2 = [lemm2.lemmatize(word) for word in tokenized2]
lemmatized2

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged2


morph = pymorphy2.MorphAnalyzer()
lemmas2 = [morph.parse(token)[0].normal_form for token in tokenized2]

tokenized2

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Pigmalion.txt", 'r', encoding = 'cp1251', errors='ignore') as f2:
    text2 = f2.read()
tokenized2 = nltk.word_tokenize(text2)
stemmed2 = [stemmer.stem(word) for word in tokenized2]
stemmed2
# Out:
# ['бернард',
#  'шо',
#  'пигмалион',
#  '(',
#  'перевод',
#  'п.в',
#  '.',
#  'мелков',
#  ',',
#  'н.л',
#  '.',
#  'рахманов',
#  ')',
#  'предислов',
#  'как',
#  'мы',
#  'увид',
#  'дальш',
#  ',',
#  '«',
#  'пигмалион',
#  '»',
#  'нужда',
#  'не',
#  'в',
#  'предислов',
#  ',',
#  'а',
#  'в',
#  'продолжен',
#  ',',
#  'котор',
#  'я',
#  'и',
#  'снабд',
#  'пьес',
#  'в',
#  'должн',
#  'мест',
#  '.',
#  'англичан',
#  'не',
#  'уважа',
#  'родн',
#  'язык',
#  'и',
#  'упорн',
#  'не',
#  'жела',
#  'уч',
#  'дет',
#  'говор',
#  'на',
#  'нем',
#  '.',
#  'написан',
#  'слов',
#  'у',
#  'них',
#  'стол',
#  'чудовищн',
#  ',',
#  'что',
#  'человек',
#  'не',
#  'науч',
#  'сам',
#  'произнос',
#  'их',
#  '.',
#  'ни',
#  'один',
#  'англичанин',
#  'не',
#  'откроет',
#  'рта',
#  'без',
#  'тог',
#  ',',
#  'чтоб',
#  'не',
#  'вызва',
#  'к',
#  'себ',
#  'ненавист',
#  'ил',
#  'презрен',
#  'у',
#  'друг',
#  'англичанин',
#  '.',
#  'немецк',
#  'и',
# ...

# %%
tokenized3 = nltk.word_tokenize(text3)
tokenized3

tagged3 = nltk.pos_tag(tokenized3)
tagged3


lemm3 = WordNetLemmatizer()
lemmatized3 = [lemm3.lemmatize(word) for word in tokenized3]
lemmatized3

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged3


morph = pymorphy2.MorphAnalyzer()
lemmas3 = [morph.parse(token)[0].normal_form for token in tokenized3]

tokenized3

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Telezhka_s_yablokami.txt", 'r', encoding = 'cp1251', errors='ignore') as f3:
    text3 = f3.read()
tokenized3 = nltk.word_tokenize(text3)
stemmed3 = [stemmer.stem(word) for word in tokenized3]
stemmed3
# Out:
# ['приятн',
#  'чтен',
#  '!',
#  'действ',
#  'перв',
#  'приемн',
#  'в',
#  'королевск',
#  'дворц',
#  '.',
#  'справ',
#  'и',
#  'слев',
#  '—',
#  'два',
#  'письмен',
#  'стол',
#  ',',
#  'поставлен',
#  'так',
#  'образ',
#  ',',
#  'что',
#  'межд',
#  'ним',
#  'оста',
#  'мног',
#  'свободн',
#  'мест',
#  '.',
#  'перед',
#  'кажд',
#  'стол',
#  'кресл',
#  'для',
#  'посетител',
#  '.',
#  'по\xadсредин',
#  'задн',
#  'стен',
#  '—',
#  'двер',
#  '.',
#  'час',
#  'показыва',
#  'нача',
#  'двенадцат',
#  ';',
#  'видн',
#  'но',
#  'освещен',
#  ',',
#  'что',
#  'дел',
#  'происход',
#  'ясн',
#  'солнечн',
#  'утр',
#  '.',
#  'семпрон',
#  ',',
#  'щеголеват',
#  'и',
#  'ещ',
#  'сравнительн',
#  'молод',
#  ',',
#  'сид',
#  'в',
#  'про\xadфил',
#  'к',
#  'зрител',
#  'за',
#  'стол',
#  'слев',
#  'и',
#  'разбира',
#  'королевск',
#  'почт',
#  '.',
#  'пам\xadфил',
#  ',',
#  'бол',
#  'пожил',
#  ',',
#  'сид',
#  'за',
#  'стол',
#  'справ',
#  ',',
# ...

# %%
tokenized4 = nltk.word_tokenize(text4)
tokenized4

tagged4 = nltk.pos_tag(tokenized4)
tagged4


lemm4 = WordNetLemmatizer()
lemmatized4 = [lemm4.lemmatize(word) for word in tokenized4]
lemmatized4

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged4


morph = pymorphy2.MorphAnalyzer()
lemmas4 = [morph.parse(token)[0].normal_form for token in tokenized4]

tokenized4

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Uchenik_dyavola.txt", 'r', encoding = 'cp1251', errors='ignore') as f4:
    text4 = f4.read()
tokenized1 = nltk.word_tokenize(text4)
stemmed4 = [stemmer.stem(word) for word in tokenized4]
stemmed4
# Out:
# ['приятн',
#  'чтен',
#  '!',
#  'бернард',
#  'шо',
#  'ученик',
#  'дьявол',
#  'действ',
#  'перв',
#  'зим',
#  '1777',
#  'год',
#  ',',
#  'в',
#  'уныл',
#  'час',
#  'межд',
#  'черн',
#  'ноч',
#  'и',
#  'хмур',
#  'утр',
#  ',',
#  'миссис',
#  'дадж',
#  'бодрств',
#  'в',
#  'сво',
#  'дом',
#  'на',
#  'окраин',
#  'городк',
#  'уэбстербридж',
#  ',',
#  'штат',
#  'нью-хэмпшир',
#  ',',
#  'в',
#  'кухн',
#  ',',
#  'котор',
#  'в',
#  'то',
#  'же',
#  'врем',
#  'служ',
#  'и',
#  'жил',
#  'комнат',
#  '.',
#  'миссис',
#  'дадж',
#  'нельз',
#  'назва',
#  'привлекательн',
#  '.',
#  'ноч',
#  ',',
#  'проведен',
#  'без',
#  'сна',
#  ',',
#  'не',
#  'крас',
#  'женщин',
#  ',',
#  'а',
#  'миссис',
#  'дадж',
#  'и',
#  'в',
#  'лучш',
#  'минут',
#  'сво',
#  'жизн',
#  'кажет',
#  'угрюм',
#  'и',
#  'мрачн',
#  'от',
#  'суров',
#  'складок',
#  'на',
#  'лиц',
#  ',',
#  'котор',
#  'говор',
#  'о',
#  'крут',
#  'нрав',
#  'и',
#  'непомерн',
#  'гордост',
# ...

# %%
tokenized5 = nltk.word_tokenize(text5)
tokenized5

tagged5 = nltk.pos_tag(tokenized5)
tagged5


lemm5 = WordNetLemmatizer()
lemmatized5 = [lemm5.lemmatize(word) for word in tokenized5]
lemmatized5

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged5


morph = pymorphy2.MorphAnalyzer()
lemmas5 = [morph.parse(token)[0].normal_form for token in tokenized5]

tokenized5

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Mayor_Barbara.txt", 'r', encoding = 'cp1251', errors='ignore') as f5:
    text5 = f5.read()
tokenized5 = nltk.word_tokenize(text5)
stemmed5 = [stemmer.stem(word) for word in tokenized5]
stemmed5
# Out:
# ['бернард',
#  'шо',
#  '«',
#  'майор',
#  'барбар',
#  '»',
#  'дискусс',
#  'в',
#  'трех',
#  'действ',
#  ',',
#  '1906',
#  'г.',
#  'перевод',
#  'пьес',
#  'н.',
#  'дарузес',
#  ',',
#  'перевод',
#  'предислов',
#  'н.',
#  'рахманов',
#  ',',
#  'примечан',
#  'и',
#  'послеслов',
#  'и.',
#  'в.',
#  'ступников',
#  '.',
#  'текст',
#  'привед',
#  'по',
#  'издан',
#  ':',
#  'бернард',
#  'шо',
#  '.',
#  'полн',
#  'собран',
#  'пьес',
#  'в',
#  'шест',
#  'том',
#  'под',
#  'общ',
#  'редакц',
#  'а.',
#  'а.',
#  'аникст',
#  ',',
#  'н.',
#  'я.',
#  'дьяконов',
#  ',',
#  'ю.',
#  'в.',
#  'ковалев',
#  ',',
#  'а.',
#  'г.',
#  'образцов',
#  ',',
#  'а.',
#  'с.',
#  'ромм',
#  ',',
#  'б.',
#  'а.',
#  'станчиц',
#  ',',
#  'и.',
#  'в.',
#  'ступников',
#  ',',
#  'трет',
#  'том',
#  '.',
#  'л.',
#  ':',
#  '«',
#  'искусств',
#  '»',
#  ',',
#  'ленинградск',
#  'отделен',
#  ',',
#  '1979',
#  '.',
#  'предислов',
#  'перв',
#  'помощ',
#  'критик',
# ...

# %%
tokenized6 = nltk.word_tokenize(text6)
tokenized6

tagged6 = nltk.pos_tag(tokenized6)
tagged6


lemm6 = WordNetLemmatizer()
lemmatized6 = [lemm6.lemmatize(word) for word in tokenized6]
lemmatized6

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged6


morph = pymorphy2.MorphAnalyzer()
lemmas6 = [morph.parse(token)[0].normal_form for token in tokenized6]

tokenized6

stemmer = SnowballStemmer(language='russian')
with open("C:\\Users\\User\\Downloads\\Nazad_k_Mafusailu.txt", 'r', encoding = 'cp1251', errors='ignore') as f6:
    text6 = f6.read()
tokenized6 = nltk.word_tokenize(text6)
stemmed6 = [stemmer.stem(word) for word in tokenized6]
stemmed6
# Out:
# ['бернард',
#  'шо',
#  'назад',
#  'к',
#  'мафусаил',
#  ':',
#  '#',
#  'c_001',
#  'метабиологическ',
#  'пенталог',
#  '1918',
#  '–',
#  '1920',
#  'полвек',
#  'безвер',
#  'на',
#  'зар',
#  'дарвинизм',
#  'как-т',
#  '(',
#  'в',
#  'начал',
#  '1860-х',
#  'год',
#  ')',
#  'я',
#  ',',
#  'тогд',
#  'ещ',
#  'совс',
#  'малыш',
#  ',',
#  'очут',
#  'в',
#  'дублинск',
#  'книжн',
#  'и',
#  'писчебумажн',
#  'лавочк',
#  'на',
#  'камден-стр',
#  'вмест',
#  'со',
#  'сво',
#  'нян',
#  ',',
#  '—',
#  'он',
#  'дела',
#  'там',
#  'какие-т',
#  'покупк',
#  '.',
#  'вслед',
#  'за',
#  'нам',
#  'вошел',
#  'почтен',
#  'вид',
#  'пожил',
#  'джентльм',
#  ',',
#  'решительн',
#  'шагнул',
#  'к',
#  'прилавк',
#  'и',
#  'властн',
#  'тон',
#  'потребова',
#  'сочинен',
#  'знаменит',
#  'буффон',
#  ':',
#  '#',
#  'c_002',
#  '.',
#  'мо',
#  'собствен',
#  'сочинен',
#  'в',
#  'то',
#  'врем',
#  'ещ',
#  'не',
#  'был',
#  'написа',
#  ',',
#  'инач',
# ...
